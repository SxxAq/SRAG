# %% [markdown]
# ## Data Ingestion

# %%
### Document structure
from langchain_core.documents import Document

# %%
doc=Document(
  page_content="This is the main content of the File",
  metadata={
    "source":"test.txt",
    "pages":1,
    "author":"Saalim Aqueel",
    "date_created":"2025-11-25"
  }
)
doc
# Out:
# Document(metadata={'source': 'test.txt', 'pages': 1, 'author': 'Saalim Aqueel', 'date_created': '2025-11-25'}, page_content='This is the main content of the File')

# %%
## Create a simple txt file
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_text = {
    "../data/text_files/refund_policy.txt": """
Our refund policy allows customers to request a refund within 30 days of purchase.
Refunds are processed within 5–7 business days after approval. Physical products must
be returned in original packaging, while digital products are eligible for refunds only
in cases where technical issues cannot be resolved by our support team.

Customers must submit a refund request through the support portal. Once submitted, our
team reviews the request and may ask for transaction details or additional verification.
Repeated refund requests for the same product may result in account restrictions.
    """,

    "../data/text_files/authentication_guide.md": """
# API Authentication Guide

All API requests must include a valid API key. Developers can generate and manage keys
from the Developer Dashboard. Use the following header format:

    Authorization: Bearer <YOUR_API_KEY>

Expired or revoked keys will result in a 401 Unauthorized response. API keys should be
stored securely and never exposed in client-side code. For rotating keys, the old key
remains active for 24 hours to ensure smooth migration.
    """,

    "../data/text_files/leave_policy.txt": """
Employees are entitled to 18 annual leaves, 12 casual leaves, and 10 sick leaves per year.
Annual leaves can be carried forward up to a maximum of 30 days. Casual and sick leaves
cannot be carried forward.

Unapproved leaves lead to salary deductions as per the HR compliance rules. Employees
must apply for leave at least 2 days in advance except in medical emergencies. A medical
certificate is required for sick leave exceeding 3 consecutive days.
    """,

    "../data/text_files/supervised_vs_unsupervised.txt": """
Supervised learning uses labeled datasets to train models, enabling tasks such as 
classification, regression, and prediction. Common algorithms include Logistic Regression, 
Support Vector Machines, Random Forest, and Gradient Boosting.

Unsupervised learning deals with unlabeled data and aims to uncover hidden patterns.
Key techniques include clustering (K-Means, DBSCAN), dimensionality reduction (PCA, t-SNE),
and association rule mining (Apriori, FP-Growth). The selection of approach depends on 
data availability and the problem type.

In modern machine learning systems, semi-supervised learning and self-supervised learning
bridge the gap by leveraging a small amount of labeled data with large volumes of unlabelled data.
    """,

    "../data/text_files/onboarding_guide.md": """
## User Onboarding Manual

### Introduction
The onboarding flow helps new users get started quickly by verifying identity and setting up
initial preferences. Users must verify their email before accessing premium features.

### Dashboard Overview
The dashboard contains modules for analytics, billing, user settings, integration management,
and usage insights. Each module includes contextual tooltips to guide new users.

### Troubleshooting
If email verification fails, users should:
- Check spam or promotions folder
- Ensure the email address is typed correctly
- Request a new verification link (expires in 15 minutes)
- Contact support if the issue persists
    """,

    "../data/text_files/iron_deficiency_info.txt": """
Iron deficiency commonly leads to fatigue, pale skin, frequent headaches, dizziness, 
and brittle nails. Severe deficiency may result in iron-deficiency anemia.

Diagnosis typically involves hemoglobin tests, ferritin level checks, and evaluation of
dietary habits. Treatment includes iron supplements, vitamin C intake for improved 
absorption, and increased consumption of leafy vegetables, red meat, and beans.

If untreated, long-term iron deficiency can cause cognitive impairment and reduced immunity.
    """,

    "../data/text_files/billing_faq.txt": """
Subscriptions renew automatically unless canceled before the next billing cycle. Auto-renewal
can be turned off from the Billing Settings page. Once disabled, users retain access until the
end of the current billing period.

Refunds for auto-renewals are provided only if the request is submitted within 48 hours.
Proration is not supported. Failed transactions may temporarily restrict access until payment
is completed.

Invoices are available for download under Account → Billing → Invoices.
    """,

    "../data/text_files/vector_embeddings_explained.txt": """
Vector embeddings convert text into high-dimensional numerical representations that reflect
semantic meaning. They allow similarity search even when keywords differ, making them core
to Retrieval Augmented Generation (RAG) systems.

Embedding models such as BERT, Sentence Transformers, and OpenAI's text-embedding models
produce dense vector outputs. These vectors are stored in vector databases like FAISS,
Pinecone, Milvus, or Weaviate.

During retrieval, similarity metrics such as cosine similarity or dot product help identify
the most relevant stored chunks. High-quality chunking, metadata tagging, and prompt design
greatly improve retrieval accuracy.
    """
}

for filepath,content in sample_text.items():
  with open(filepath,'w',encoding="utf-8") as f:
    f.write(content)
print(" Sample Files created.")
# Out:
#  Sample Files created.

# %%
### textloader
from langchain_community.document_loaders import TextLoader

documents=[]
for path in sample_text.keys():
  loader=TextLoader(path,encoding="utf-8")
  docs=loader.load()
  documents.extend(docs)

# %%
### Directory loader
from langchain_community.document_loaders import DirectoryLoader

dir_loader=DirectoryLoader("../data/text_files",
                           glob=["**/*.txt","**/*.md"],
                           loader_cls=TextLoader,
                           loader_kwargs={"encoding":"utf-8"},
                           show_progress=True)
documents1=dir_loader.load()
# Out:
# 100%|██████████| 8/8 [00:00<00:00, 8848.74it/s]

# %%
### Directory loader
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader

dir_loader=DirectoryLoader("../data/pdf",
                           glob="**/*.pdf",
                           loader_cls=PyPDFLoader,
                           
                           show_progress=True)
documents1=dir_loader.load()
documents1
# Out:
# 100%|██████████| 4/4 [00:02<00:00,  1.62it/s]
# ...
